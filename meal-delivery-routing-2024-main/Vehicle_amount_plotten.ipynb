# %%
import pandas as pd 
import support_functions as sf
import matplotlib.pyplot as plt

# %%
df = sf.import_pickle_file('resultwednesday (1).pickle')
plt.plot(df['vehicle_num'], df['a'])
plt.title('Vehicle Number vs. a')
plt.xlabel('Vehicle Number')
plt.ylabel('a')
plt.show()
